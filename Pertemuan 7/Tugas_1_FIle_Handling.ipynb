# %%
def writeBiodata():
    file = open("Biodata.txt", "w")

    nama = input("Masukkan nama anda: ")
    usia = input("Masukkan usia anda: ")
    alamat = input("Masukkan alamat anda: ")
    email = input("Masukkan email aktif: ")

    file.write("Nama: " + nama + "\n")
    file.write("Usia: " + usia + "\n")
    file.write("Alamat: " + alamat + "\n")
    file.write("Email: " + email + "\n")

    file.close()
    print("Data berhasil disimpan\n")

def readBiodata():
    file = open("Biodata.txt", "r")

    text = file.read()
    print("=== Isi Biodata ===")
    print(text)

    file.close()

writeBiodata()
readBiodata()
# Out:
# Masukkan nama anda: olap
# Masukkan usia anda: 31
# Masukkan alamat anda: malang
# Masukkan email aktif: olap@yahoo.com
# Data berhasil disimpan
#
# === Isi Biodata ===
# Nama: olap
# Usia: 31
# Alamat: malang
# Email: olap@yahoo.com
