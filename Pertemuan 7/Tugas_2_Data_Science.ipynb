# %%
import pandas as pd

data = {
    "Negara" : ["Australia", "Argentina", "Armenia", "Azerbaijan", "Sadi Arabia", "Oman", "Mexico", "Spain", "Canada", "Malaysia"],
    "Ibu Kota" : ["Canberra", "Buenos Aires", "Yerevan", "Baku", "Riyadh", "Muscat", "Mexico City", "Madrid", "Ottawa", "Kuala Lumpur"],
    "Benua" : ["Oceania", "Amerika Selatan", "Asia", "Asia", "Asia", "Asia", "Amerika Selatan", "Europa", "Amerika", "Asia"],
    "Luas" : ["76", "27", "297", "866", "214", "309", "196", "50", "998", "329"],
    "Populasi" : ["26", "46", "30", "10", "36", "46", "130", "47", "39", "34"]
}

df = pd.DataFrame(data)

df.to_csv('negara_coba.csv')

print("=== Data berhasil disimpan ke CSV ===")
print(df)
# Out:
# === Data berhasil disimpan ke CSV ===
#         Negara      Ibu Kota            Benua Luas Populasi
# 0    Australia      Canberra          Oceania   76       26
# 1    Argentina  Buenos Aires  Amerika Selatan   27       46
# 2      Armenia       Yerevan             Asia  297       30
# 3   Azerbaijan          Baku             Asia  866       10
# 4  Sadi Arabia        Riyadh             Asia  214       36
# 5         Oman        Muscat             Asia  309       46
# 6       Mexico   Mexico City  Amerika Selatan  196      130
# 7        Spain        Madrid           Europa   50       47
# 8       Canada        Ottawa          Amerika  998       39
# 9     Malaysia  Kuala Lumpur             Asia  329       34
