# %%
import pandas as pd

df = pd.read_csv('/content/sample_data/cobanegara.csv')

mean_populasi = df["Populasi"].mean()
std_luas = df["Luas"].std()

print("========================= Data Negara ===============================")
print(df)

print("\nRata-rata Populasi:", mean_populasi)
print("Standar Deviasi Area:", std_luas)
# Out:
# ========================= Data Negara ===============================
#          Negara      Ibu Kota              Benua  Luas  Populasi
# 0     Australia      Canberra  Australia/Oseania    76        26
# 1     Agentina   Buenos Aires    Amerika Selatan    27        46
# 2       Armenia       Yerevan               Asia   297        30
# 3   Azerbaijan           Baku               Asia   866        10
# 4  Saudi Arabia        Riyadh               Asia   214        36
# 5          Oman        Muscat               Asia   309        46
# 6        Mexico   Mexico City      Amerika Utara   196       130
# 7         Spain        Madrid              Eropa    50        47
# 8        Canada        Ottawa      Amerika Utara   998        39
# 9      Malaysia  Kuala Lumpur               Asia   329        34
#
# Rata-rata Populasi: 44.4
# Standar Deviasi Area: 333.46723977026585
